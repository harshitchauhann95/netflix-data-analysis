# %% [markdown]
# # 🎨 03. Netflix Data Visualization & Export
#
# Generating publication-quality charts and exporting figures to the visuals/ directory.

# %%
import os
import sys

sys.path.append(os.path.abspath('..'))
from src.data_loader import load_processed_data
from src.visualize import (
    plot_content_distribution,
    plot_release_year_trends,
    plot_top_countries,
    plot_rating_distribution,
    plot_top_genres
)

# %%
df = load_processed_data('../data/processed/netflix_cleaned.csv')
visuals_dir = '../visuals'
os.makedirs(visuals_dir, exist_ok=True)

# %%
plot_content_distribution(df, save_path=os.path.join(visuals_dir, 'content_type_distribution.png'))

# %%
plot_release_year_trends(df, save_path=os.path.join(visuals_dir, 'release_year_trend.png'))

# %%
plot_top_countries(df, save_path=os.path.join(visuals_dir, 'top_countries.png'))

# %%
plot_rating_distribution(df, save_path=os.path.join(visuals_dir, 'rating_distribution.png'))

# %%
plot_top_genres(df, save_path=os.path.join(visuals_dir, 'top_genres.png'))
